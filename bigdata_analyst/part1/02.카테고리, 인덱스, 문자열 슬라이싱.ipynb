# %%
import pandas as pd
df = pd.read_csv('type1_data1.csv')

# %%
#1. 'subscribed' 컬럼에서 가장 빈도수가 많은 날짜를 구하시오

# %%
df['subscribed'].value_counts()
# Out:
# 2025-02-17    16
# 2024-06-21     3
# 2024-04-03     2
# 2024-07-29     2
# 2024-05-28     2
#               ..
# 2024-07-08     1
# 2024-07-20     1
# 2024-06-10     1
# 2024-02-01     1
# 2024-05-20     1
# Name: subscribed, Length: 96, dtype: int64

# %%
max_sub = df['subscribed'].max()
max_sub
# Out:
# '2025-02-17'

# %%
#2. 앞에서 구한 날짜의 일(day) 값을 정수로 구하시오

# %%
#바로 기억 안나는 ㅠㅠ

# %%
int(max_sub[8:])
#또는
int(max_sub[-2:])
# Out:
# 17
